# %%
import pandas as pd

fed_files = ["Mortgage30US.csv", "RRVRUSQ156n.csv", "CPIAUCSL.csv"]

dfs = [pd.read_csv(f, parse_dates=True, index_col=0) for f in fed_files]

# %%
dfs[0]
# Out:
#             MORTGAGE30US
# DATE
# 1971-04-02          7.33
# 1971-04-09          7.31
# 1971-04-16          7.31
# 1971-04-23          7.31
# 1971-04-30          7.29
# ...                  ...
# 2024-01-04          6.62
# 2024-01-11          6.66
# 2024-01-18          6.60
# 2024-01-25          6.69
# 2024-02-01          6.63
#
# [2758 rows x 1 columns]

# %%
dfs[1]
# Out:
#             RRVRUSQ156N
# DATE
# 1956-01-01          6.2
# 1956-04-01          5.9
# 1956-07-01          6.3
# 1956-10-01          5.8
# 1957-01-01          5.3
# ...                 ...
# 2022-10-01          5.8
# 2023-01-01          6.4
# 2023-04-01          6.3
# 2023-07-01          6.6
# 2023-10-01          6.6
#
# [272 rows x 1 columns]

# %%
dfs[2]
# Out:
#             CPIAUCSL
# DATE
# 1947-01-01    21.480
# 1947-02-01    21.620
# 1947-03-01    22.000
# 1947-04-01    22.000
# 1947-05-01    21.950
# ...              ...
# 2023-08-01   306.269
# 2023-09-01   307.481
# 2023-10-01   307.619
# 2023-11-01   307.917
# 2023-12-01   308.850
#
# [924 rows x 1 columns]

# %%
fed_data = pd.concat(dfs, axis=1)

# %%
fed_data
# Out:
#             MORTGAGE30US  RRVRUSQ156N  CPIAUCSL
# DATE
# 1947-01-01           NaN          NaN     21.48
# 1947-02-01           NaN          NaN     21.62
# 1947-03-01           NaN          NaN     22.00
# 1947-04-01           NaN          NaN     22.00
# 1947-05-01           NaN          NaN     21.95
# ...                  ...          ...       ...
# 2024-01-04          6.62          NaN       NaN
# 2024-01-11          6.66          NaN       NaN
# 2024-01-18          6.60          NaN       NaN
# 2024-01-25          6.69          NaN       NaN
# 2024-02-01          6.63          NaN       NaN
#
# [3598 rows x 3 columns]

# %%
fed_data.tail(50)
# Out:
#             MORTGAGE30US  RRVRUSQ156N  CPIAUCSL
# DATE
# 2023-04-13          6.27          NaN       NaN
# 2023-04-20          6.39          NaN       NaN
# 2023-04-27          6.43          NaN       NaN
# 2023-05-01           NaN          NaN   303.294
# 2023-05-04          6.39          NaN       NaN
# 2023-05-11          6.35          NaN       NaN
# 2023-05-18          6.39          NaN       NaN
# 2023-05-25          6.57          NaN       NaN
# 2023-06-01          6.79          NaN   303.841
# 2023-06-08          6.71          NaN       NaN
# 2023-06-15          6.69          NaN       NaN
# 2023-06-22          6.67          NaN       NaN
# 2023-06-29          6.71          NaN       NaN
# 2023-07-01           NaN          6.6   304.348
# 2023-07-06          6.81          NaN       NaN
# 2023-07-13          6.96          NaN       NaN
# 2023-07-20          6.78          NaN       NaN
# 2023-07-27          6.81          NaN       NaN
# 2023-08-01           NaN          NaN   306.269
# 2023-08-03          6.90          NaN       NaN
# 2023-08-10          6.96          NaN       NaN
# 2023-08-17          7.09          NaN       NaN
# 2023-08-24          7.23          NaN       NaN
# 2023-08-31          7.18          NaN       NaN
# 2023-09-01           NaN          NaN   307.481
# 2023-09-07          7.12          NaN       NaN
# 2023-09-14          7.18          NaN       NaN
# 2023-09-21          7.19          NaN       NaN
# 2023-09-28          7.31          NaN       NaN
# 2023-10-01           NaN          6.6   307.619
# 2023-10-05          7.49          NaN       NaN
# 2023-10-12          7.57          NaN       NaN
# 2023-10-19          7.63          NaN       NaN
# 2023-10-26          7.79          NaN       NaN
# 2023-11-01           NaN          NaN   307.917
# Out:
#      RegionID  SizeRank       RegionName RegionType StateName  2008-02-02  \
# 0      102001         0    United States    country       NaN    177000.0
# 1      394913         1     New York, NY        msa        NY    395000.0
# 2      753899         2  Los Angeles, CA        msa        CA    450000.0
# 3      394463         3      Chicago, IL        msa        IL    228000.0
# 4      394514         4       Dallas, TX        msa        TX    137000.0
# ..        ...       ...              ...        ...       ...         ...
# 153    394380       232         Bend, OR        msa        OR         NaN
# 154    395009       237  Punta Gorda, FL        msa        FL    154750.0
# 155    394960       242  Panama City, FL        msa        FL         NaN
# 156    395079       274    Sebastian, FL        msa        FL         NaN
# 157    394493       285      Concord, NH        msa        NH         NaN
#
#      2008-02-09  2008-02-16  2008-02-23  2008-03-01  ...  2023-10-07  \
# 0      171500.0    173000.0    169000.0    177400.0  ...    330000.0
# 1      406000.0    410000.0    410000.0    386750.0  ...    560000.0
# 2      460000.0    475000.0    482500.0    460000.0  ...    890000.0
# 3      220000.0    225000.0    215000.0    229500.0  ...    290000.0
# 4      130042.0    140000.0    137250.0    139000.0  ...    375050.0
# ..          ...         ...         ...         ...  ...         ...
# 153         NaN         NaN         NaN         NaN  ...         NaN
# 154    150000.0    158000.0    155000.0    141000.0  ...    260000.0
# 155         NaN         NaN         NaN         NaN  ...    350000.0
# 156         NaN         NaN         NaN         NaN  ...    357450.0
# 157         NaN         NaN         NaN         NaN  ...         NaN
#
#      2023-10-14  2023-10-21  2023-10-28  2023-11-04  2023-11-11  2023-11-18  \
# 0      330000.0    334900.0    330000.0    333500.0    325000.0    330000.0
# 1      555000.0    563500.0    560000.0    550000.0    551500.0    580000.0
# 2      908500.0    885500.0    900000.0    885000.0    905000.0    910000.0
# 3      289000.0    295000.0    282500.0    285000.0    290000.0    286000.0
# 4      370000.0    379000.0    378000.0    373750.0    380000.0    375000.0
# ..          ...         ...         ...         ...         ...         ...
# 153         NaN         NaN         NaN         NaN         NaN         NaN
# 154    306500.0    314500.0    300000.0    290000.0    310000.0    319000.0
# 155    325000.0    327500.0    335000.0    359000.0    335000.0    355000.0
# 156    279950.0    335000.0    361250.0    362165.0    304000.0    367000.0
# 157         NaN         NaN         NaN         NaN         NaN         NaN
#
#      2023-11-25  2023-12-02  2023-12-09
# 0      320000.0    335000.0    329900.0
# 1      560000.0    570000.0    565000.0
# 2      887000.0    898000.0    885000.0
# 3      272750.0    308000.0    285000.0
# 4      373900.0    375000.0    367244.0
# ..          ...         ...         ...
# 153         NaN    695000.0    705500.0
# 154    285000.0    315000.0    306000.0
# 155    350000.0    312000.0    362500.0
# 156    347500.0    380000.0    347000.0
# 157         NaN    369967.0    450000.0
#
# [158 rows x 833 columns]

# %%
dfs = [pd.DataFrame(df.iloc[0,5:]) for df in dfs]

# %%
dfs[0]
# Out:
#                    0
# 2008-02-02  177000.0
# 2008-02-09  171500.0
# 2008-02-16  173000.0
# 2008-02-23  169000.0
# 2008-03-01  177400.0
# ...              ...
# 2023-11-11  325000.0
# 2023-11-18  330000.0
# 2023-11-25  320000.0
# 2023-12-02  335000.0
# 2023-12-09  329900.0
#
# [828 rows x 1 columns]

# %%
dfs[1]
# Out:
#                         0
# 1996-02-29  100430.220772
# 1996-03-31  100684.488605
# 1996-04-30  101223.508699
# 1996-05-31  101956.529753
# 1996-06-30  102747.986673
# ...                   ...
# 2023-08-31  348889.175118
# 2023-09-30  348559.625229
# 2023-10-31  347450.262713
# 2023-11-30  346104.227776
# 2023-12-31  344000.042191
#
# [335 rows x 1 columns]

# %%
for df in dfs:
    df.index = pd.to_datetime(df.index)
    df["month"] = df.index.to_period("M")

# %%
dfs[1]
# Out:
#                         0    month
# 1996-02-29  100430.220772  1996-02
# 1996-03-31  100684.488605  1996-03
# 1996-04-30  101223.508699  1996-04
# 1996-05-31  101956.529753  1996-05
# 1996-06-30  102747.986673  1996-06
# ...                   ...      ...
# 2023-08-31  348889.175118  2023-08
# 2023-09-30  348559.625229  2023-09
# 2023-10-31  347450.262713  2023-10
# 2023-11-30  346104.227776  2023-11
# 2023-12-31  344000.042191  2023-12
#
# [335 rows x 2 columns]

# %%
price_data = dfs[0].merge(dfs[1], on="month")

# %%
price_data.index = dfs[0].index

# %%
price_data
# Out:
#                  0_x    month            0_y
# 2008-02-02  177000.0  2008-02  194418.615271
# 2008-02-09  171500.0  2008-02  194418.615271
# 2008-02-16  173000.0  2008-02  194418.615271
# 2008-02-23  169000.0  2008-02  194418.615271
# 2008-03-01  177400.0  2008-03  193129.815004
# ...              ...      ...            ...
# 2023-11-11  325000.0  2023-11  346104.227776
# 2023-11-18  330000.0  2023-11  346104.227776
# 2023-11-25  320000.0  2023-11  346104.227776
# 2023-12-02  335000.0  2023-12  344000.042191
# 2023-12-09  329900.0  2023-12  344000.042191
#
# [828 rows x 3 columns]

# %%
del price_data["month"]
price_data.columns = ["price", "value"]

# %%
price_data
# Out:
#                price          value
# 2008-02-02  177000.0  194418.615271
# 2008-02-09  171500.0  194418.615271
# 2008-02-16  173000.0  194418.615271
# 2008-02-23  169000.0  194418.615271
# 2008-03-01  177400.0  193129.815004
# ...              ...            ...
# 2023-11-11  325000.0  346104.227776
# 2023-11-18  330000.0  346104.227776
# 2023-11-25  320000.0  346104.227776
# 2023-12-02  335000.0  344000.042191
# 2023-12-09  329900.0  344000.042191
#
# [828 rows x 2 columns]

# %%
fed_data = fed_data.dropna()

# %%
fed_data
# Out:
#             MORTGAGE30US  RRVRUSQ156N  CPIAUCSL
# DATE
# 1971-04-02          7.33          5.3     40.10
# 1971-04-09          7.31          5.3     40.10
# 1971-04-16          7.31          5.3     40.10
# 1971-04-23          7.31          5.3     40.10
# 1971-04-30          7.29          5.3     40.10
# ...                  ...          ...       ...
# 2024-01-04          6.62          6.6    308.85
# 2024-01-11          6.66          6.6    308.85
# 2024-01-18          6.60          6.6    308.85
# 2024-01-25          6.69          6.6    308.85
# 2024-02-01          6.63          6.6    308.85
#
# [3306 rows x 3 columns]

# %%
fed_data.tail(20)
# Out:
#             MORTGAGE30US  RRVRUSQ156N  CPIAUCSL
# DATE
# 2023-10-05          7.49          6.6   307.619
# 2023-10-12          7.57          6.6   307.619
# 2023-10-19          7.63          6.6   307.619
# 2023-10-26          7.79          6.6   307.619
# 2023-11-01          7.79          6.6   307.917
# 2023-11-02          7.76          6.6   307.917
# 2023-11-09          7.50          6.6   307.917
# 2023-11-16          7.44          6.6   307.917
# 2023-11-22          7.29          6.6   307.917
# 2023-11-30          7.22          6.6   307.917
# 2023-12-01          7.22          6.6   308.850
# 2023-12-07          7.03          6.6   308.850
# 2023-12-14          6.95          6.6   308.850
# 2023-12-21          6.67          6.6   308.850
# 2023-12-28          6.61          6.6   308.850
# 2024-01-04          6.62          6.6   308.850
# 2024-01-11          6.66          6.6   308.850
# 2024-01-18          6.60          6.6   308.850
# 2024-01-25          6.69          6.6   308.850
# 2024-02-01          6.63          6.6   308.850

# %%
from datetime import timedelta

fed_data.index = fed_data.index + timedelta(daya=2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 3
#       1 from datetime import timedelta
# ----> 3 fed_data.index = fed_data.index + timedelta(daya=2)
#
# TypeError: 'daya' is an invalid keyword argument for __new__()

# %%
from datetime import timedelta

fed_data.index = fed_data.index + timedelta(days=2)

# %%
fed_data
# Out:
#             MORTGAGE30US  RRVRUSQ156N  CPIAUCSL
# DATE
# 1971-04-04          7.33          5.3     40.10
# 1971-04-11          7.31          5.3     40.10
# 1971-04-18          7.31          5.3     40.10
# 1971-04-25          7.31          5.3     40.10
# 1971-05-02          7.29          5.3     40.10
# ...                  ...          ...       ...
# 2024-01-06          6.62          6.6    308.85
# 2024-01-13          6.66          6.6    308.85
# 2024-01-20          6.60          6.6    308.85
# 2024-01-27          6.69          6.6    308.85
# 2024-02-03          6.63          6.6    308.85
#
# [3306 rows x 3 columns]

# %%
price_data = fed_data.merge(price_data, left_index=True, right_index=True)

# %%
price_data
# Out:
#             MORTGAGE30US  RRVRUSQ156N  CPIAUCSL     price          value
# 2008-02-02          5.68         10.1   212.174  177000.0  194418.615271
# 2008-02-09          5.67         10.1   212.687  171500.0  194418.615271
# 2008-02-16          5.72         10.1   212.687  173000.0  194418.615271
# 2008-02-23          6.04         10.1   212.687  169000.0  194418.615271
# 2008-03-01          6.24         10.1   212.687  177400.0  193129.815004
# ...                  ...          ...       ...       ...            ...
# 2023-11-04          7.76          6.6   307.917  333500.0  346104.227776
# 2023-11-11          7.50          6.6   307.917  325000.0  346104.227776
# 2023-11-18          7.44          6.6   307.917  330000.0  346104.227776
# 2023-12-02          7.22          6.6   307.917  335000.0  344000.042191
# 2023-12-09          7.03          6.6   308.850  329900.0  344000.042191
#
# [807 rows x 5 columns]

# %%
price_data.columns = ["interest", "vacancy", "cpi", "price", "value"]

# %%
price_data
# Out:
#             interest  vacancy      cpi     price          value
# 2008-02-02      5.68     10.1  212.174  177000.0  194418.615271
# 2008-02-09      5.67     10.1  212.687  171500.0  194418.615271
# 2008-02-16      5.72     10.1  212.687  173000.0  194418.615271
# 2008-02-23      6.04     10.1  212.687  169000.0  194418.615271
# 2008-03-01      6.24     10.1  212.687  177400.0  193129.815004
# ...              ...      ...      ...       ...            ...
# 2023-11-04      7.76      6.6  307.917  333500.0  346104.227776
# 2023-11-11      7.50      6.6  307.917  325000.0  346104.227776
# 2023-11-18      7.44      6.6  307.917  330000.0  346104.227776
# 2023-12-02      7.22      6.6  307.917  335000.0  344000.042191
# 2023-12-09      7.03      6.6  308.850  329900.0  344000.042191
#
# [807 rows x 5 columns]

# %%
price_data.plot.line(y="price", use_index=True)
# Out:
# <Axes: >

# %%
price_data["adj_price"] = price_data["price"] / price_data["cpi"] * 100

# %%
price_data.plot.line(y="adj_price", use_index=True)
# Out:
# <Axes: >

# %%
price_data["adj_value"] = price_data["value"] / price_data["cpi"] * 100

# %%
price_data["next_quarter"] = price_data["adj_price"].shift(-13)

# %%
price_data
# Out:
#             interest  vacancy      cpi     price          value  \
# 2008-02-02      5.68     10.1  212.174
# 2023-08-19      7.09      6.6  306.269  348000.0  348889.175118
# 2023-08-26      7.23      6.6  306.269  345000.0  348889.175118
# 2023-09-02      7.18      6.6  306.269  345000.0  348559.625229
#
#                 adj_price      adj_value   next_quarter  change
# 2008-02-02   83422.096958   91631.686857   85498.680346       1
# 2008-02-09    80634.92362   91410.671678   81316.679677       1
# 2008-02-16   81340.185343   91410.671678   83640.013382       1
# 2008-02-23   79459.487416   91410.671678   83640.013382       1
# 2008-03-01   83408.953062    90804.71068   86892.680569       1
# ...                   ...            ...            ...     ...
# 2023-08-05  114278.624347   113915.92852  108308.407785       0
# 2023-08-12   112646.07257   113915.92852  105547.923629       0
# 2023-08-19  113625.603636   113915.92852  107171.737838       0
# 2023-08-26   112646.07257   113915.92852  108795.552048       0
# 2023-09-02   112646.07257  113808.327068  106815.606281       0
#
# [794 rows x 9 columns]

# %%
price_data["change"].value_counts()
# Out:
# 0    408
# 1    386
# Name: change, dtype: int64

# %%
predictors = ["interest", "vacancy", "adj_price"]
target = "change"

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
import numpy as np

# %%
START = 260
STEP = 52

def predict(train, test, predictors, target):
    rf = RandomForestClassifier(min_samples_split=10, random_state=1)
    rf.fit(train[predictors], train[target])
    preds = rf.predict(test[predictors])
    return preds

def backtest(data, predictors, target):
    all_preds = []
    for i in range(START, data.shape[0], STEP):
        train = price_data.iloc[:i]
        test = price_data.iloc[i:(i+STEP)]
        all_preds.append(predict(train, test, predictors, target))
        
    preds = np.concatenate(all_preds)
    return preds, accuracy_score(data.iloc[START:][target], preds)

# %%
preds, accuracy = backtest(price_data, predictors,target)

# %%
accuracy
# Out:
# 0.5280898876404494

# %%
yearly = price_data.rolling(52, min_periods=1).mean()

# %%
yearly
# Out:
#             interest    vacancy         cpi          price          value  \
# 2008-02-02  5.680000  10.100000  212.174000  177000.000000  194418.615271
# 2008-02-09  5.675000  10.100000  212.430500  174250.000000  194418.615271
# 2008-02-16  5.690000  10.100000  212.516000  173833.333333  194418.615271
# 2008-02-23  5.777500  10.100000  212.558750  172625.000000  194418.615271
# 2008-03-01  5.870000  10.100000  212.584400  173580.000000  194160.855218
# ...              ...        ...         ...            ...            ...
# 2023-08-05  6.408654   6.186538  300.618404  325919.865385  338654.804873
# 2023-08-12  6.446538   6.198077  300.828962  326208.326923  338742.774327
# 2023-08-19  6.482500   6.209615  301.039519  326554.480769  338830.743781
# 2023-08-26  6.522885   6.221154  301.250077  326842.942308  338918.713235
# 2023-09-02  6.554231   6.232692  301.460635  327131.403846  339000.345191
#
#                 adj_price      adj_value   next_quarter  change
# 2008-02-02   83422.096958   91631.686857   85498.680346     1.0
# 2008-02-09   82028.510289   91521.179267   83407.680012     1.0
# 2008-02-16   81799.068640   91484.343404   83485.124469     1.0
# 2008-02-23   81214.173334   91465.925472   83523.846697     1.0
# 2008-03-01   81653.129280   91333.682514   84197.613472     1.0
# ...                   ...            ...            ...     ...
# 2023-08-05  108399.992331  112660.855835  108470.985400     0.5
# 2023-08-12  108417.355384  112609.423728  108472.041548     0.5
# 2023-08-19  108453.555573  112557.991622  108530.086308     0.5
# 2023-08-26  108470.918626  112506.559516  108623.222478     0.5
# 2023-09-02  108488.281679  112453.058151  108670.612674     0.5
#
# [794 rows x 9 columns]

# %%
yearly_ratios = [p + "_year" for p in predictors]
price_data[yearly_ratios] = price_data[predictors] / yearly[predictors]

# %%
price_data
# Out:
#             interest  vacancy      cpi     price          value  \
# 2008-02-02      5.68     10.1  212.174  177000.0  194418.615271
# 2008-02-09      5.67     10.1  212.687  171500.0  194418.615271
# 2008-02-16      5.72     10.1  212.687  173000.0  194418.615271
# 2008-02-23      6.04     10.1  212.687  169000.0  194418.615271
# 2008-03-01      6.24     10.1  212.687  177400.0  193129.815004
# ...              ...      ...      ...       ...            ...
# 2023-08-05      6.90      6.6  306.269  350000.0  348889.175118
# 2023-08-12      6.96      6.6  306.269  345000.0  348889.175118
# 2023-08-19      7.09      6.6  306.269  348000.0  348889.175118
# 2023-08-26      7.23      6.6  306.269  345000.0  348889.175118
# 2023-09-02      7.18      6.6  306.269  345000.0  348559.625229
#
#                 adj_price      adj_value   next_quarter  change  \
# 2008-02-02   83422.096958   91631.686857   85498.680346       1
# 2008-02-09    80634.92362   91410.671678   81316.679677       1
# 2008-02-16   81340.185343   91410.671678   83640.013382       1
# 2008-02-23   79459.487416   91410.671678   83640.013382       1
# 2008-03-01   83408.953062    90804.71068   86892.680569       1
# ...                   ...            ...            ...     ...
# 2023-08-05  114278.624347   113915.92852  108308.407785       0
# 2023-08-12   112646.07257   113915.92852  105547.923629       0
# 2023-08-19  113625.603636   113915.92852  107171.737838       0
# 2023-08-26   112646.07257   113915.92852  108795.552048       0
# 2023-09-02   112646.07257  113808.327068  106815.606281       0
#
#             interest_year  vacancy_year adj_price_year
# 2008-02-02       1.000000      1.000000            1.0
# 2008-02-09       0.999119      1.000000       0.983011
# 2008-02-16       1.005272      1.000000        0.99439
# 2008-02-23       1.045435      1.000000       0.978394
# 2008-03-01       1.063032      1.000000       1.021503
# ...                   ...           ...            ...
# 2023-08-05       1.076669      1.066832       1.054231
# 2023-08-12       1.079649      1.064846       1.039004
# 2023-08-19       1.093714      1.062868       1.047689
# 2023-08-26       1.108405      1.060896       1.038491
# 2023-09-02       1.095476      1.058932       1.038325
#
# [794 rows x 12 columns]

# %%
preds, accuracy = backtest(price_data, predictors + yearly_ratios, target)

# %%
accuracy
# Out:
# 0.5917602996254682

# %%
pred_match = (preds == price_data[target].iloc[START:])

# %%
pred_match[pred_match == True] = "green"
pred_match[pred_match == False] = "red"

# %%
import matplotlib.pyplot as ply

plot_data = price_data.iloc[START:].copy()

plot_data.reset_index().plot.scatter(x="index", y="adj_price", color=pred_match)
# Out:
# <Axes: xlabel='index', ylabel='adj_price'>

# %%
from sklearn.inspection import permutation_importance

rf = RandomForestClassifier(min_samples_split=10, random_state=1)
rf.fit(price_data[predictors], price_data[target])

result = permutation_importance(rf, price_data[predictors], price_data[target], n_repeats=10, random_state=1)

# %%
result["importances_mean"]
# Out:
# array([0.2429471 , 0.30163728, 0.2906801 ])

# %% [raw]
# predictors

# %%
predictors
# Out:
# ['interest', 'vacancy', 'adj_price']
